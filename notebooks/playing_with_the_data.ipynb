# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# get working directory and remove last folder
wd = os.path.dirname(os.getcwd())
os.chdir(wd)
print("Working Directory: ", os.getcwd())
# Out:
# Working Directory:  d:\Repos\student-performance

# %%
dtypes={
    'elapsed_time':np.int32,
    'event_name':'category',
    'name':'category',
    'level':np.uint8,
    'room_coor_x':np.float32,
    'room_coor_y':np.float32,
    'screen_coor_x':np.float32,
    'screen_coor_y':np.float32,
    'hover_duration':np.float32,
    'text':'category',
    'fqid':'category',
    'room_fqid':'category',
    'text_fqid':'category',
    'fullscreen':'category',
    'hq':'category',
    'music':'category',
    'level_group':'category'}

dataset_df = pd.read_csv('data/raw/train.csv', nrows=300000,dtype=dtypes)

# %%
# Wähle die ersten 200 Zeilen aus
subset_df = dataset_df.head(300000)

# Schreibe die ausgewählten Zeilen in eine neue CSV-Datei
subset_df.to_csv('data/processed/subset.csv', index=False)

# %%
dataset_df.head(5)
# Out:
#           session_id  index  elapsed_time      event_name   name  level  page
# 0  20090312431273200      0             0  cutscene_click  basic      0   NaN  \
# 1  20090312431273200      1          1323    person_click  basic      0   NaN
# 2  20090312431273200      2           831    person_click  basic      0   NaN
# 3  20090312431273200      3          1147    person_click  basic      0   NaN
# 4  20090312431273200      4          1863    person_click  basic      0   NaN
#
#    room_coor_x  room_coor_y  screen_coor_x  screen_coor_y  hover_duration
# 0  -413.991394  -159.314682          380.0          494.0             NaN  \
# 1  -413.991394  -159.314682          380.0          494.0             NaN
# 2  -413.991394  -159.314682          380.0          494.0             NaN
# 3  -413.991394  -159.314682          380.0          494.0             NaN
# 4  -412.991394  -159.314682          381.0          494.0             NaN
#
# ...

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   session_id      300000 non-null  int64
#  1   index           300000 non-null  int64
#  2   elapsed_time    300000 non-null  int32
#  3   event_name      300000 non-null  category
#  4   name            300000 non-null  category
#  5   level           300000 non-null  uint8
#  6   page            6038 non-null    float64
#  7   room_coor_x     272900 non-null  float32
#  8   room_coor_y     272900 non-null  float32
#  9   screen_coor_x   272900 non-null  float32
#  10  screen_coor_y   272900 non-null  float32
#  11  hover_duration  26281 non-null   float32
#  12  text            109555 non-null  category
#  13  fqid            209749 non-null  category
#  14  room_fqid       300000 non-null  category
#  15  text_fqid       109556 non-null  category
# ...

# %%
#dataset_df.describe()

# %%
subset_df.head()
# Out:
#           session_id  index  elapsed_time      event_name   name  level  page
# 0  20090312431273200      0             0  cutscene_click  basic      0   NaN  \
# 1  20090312431273200      1          1323    person_click  basic      0   NaN
# 2  20090312431273200      2           831    person_click  basic      0   NaN
# 3  20090312431273200      3          1147    person_click  basic      0   NaN
# 4  20090312431273200      4          1863    person_click  basic      0   NaN
#
#    room_coor_x  room_coor_y  screen_coor_x  screen_coor_y  hover_duration
# 0  -413.991394  -159.314682          380.0          494.0             NaN  \
# 1  -413.991394  -159.314682          380.0          494.0             NaN
# 2  -413.991394  -159.314682          380.0          494.0             NaN
# 3  -413.991394  -159.314682          380.0          494.0             NaN
# 4  -412.991394  -159.314682          381.0          494.0             NaN
#
# ...

# %%
subset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   session_id      300000 non-null  int64
#  1   index           300000 non-null  int64
#  2   elapsed_time    300000 non-null  int32
#  3   event_name      300000 non-null  category
#  4   name            300000 non-null  category
#  5   level           300000 non-null  uint8
#  6   page            6038 non-null    float64
#  7   room_coor_x     272900 non-null  float32
#  8   room_coor_y     272900 non-null  float32
#  9   screen_coor_x   272900 non-null  float32
#  10  screen_coor_y   272900 non-null  float32
#  11  hover_duration  26281 non-null   float32
#  12  text            109555 non-null  category
#  13  fqid            209749 non-null  category
#  14  room_fqid       300000 non-null  category
#  15  text_fqid       109556 non-null  category
# ...

# %%
#subset_df.describe()

# %%
#subset_df.hist(figsize=(10,10))

# %%
#dataset_df.hist(figsize=(10,10))

# %%
import data_preprocessing_martin as dps

subset_df = dps.adding_new_variables(subset_df)
subset_df = dps.adding_euclid_distance_variable(subset_df)
#subset_df = dps.adding_session_distance(subset_df)
subset_df.head()
#subset_df = dps.feature_engineer_steve(subset_df)
# Out:
#    level_0         session_id  index  elapsed_time      event_name   name
# 0        0  20090312431273200      0             0  cutscene_click  basic  \
# 1        2  20090312431273200      2           831    person_click  basic
# 2        3  20090312431273200      3          1147    person_click  basic
# 3        1  20090312431273200      1          1323    person_click  basic
# 4        4  20090312431273200      4          1863    person_click  basic
#
#    level  page  room_coor_x  room_coor_y  ...                           text
# 0      0   NaN  -413.991394  -159.314682  ...                      undefined  \
# 1      0   NaN  -413.991394  -159.314682  ...         Just talking to Teddy.
# 2      0   NaN  -413.991394  -159.314682  ...     I gotta run to my meeting!
# 3      0   NaN  -413.991394  -159.314682  ...  Whatcha doing over there, Jo?
# 4      0   NaN  -412.991394  -159.314682  ...            Can I come, Gramps?
#
#      fqid                       room_fqid
# ...

# %%
subset_df = dps.adding_euclid_distance_cumsum_variable(subset_df)
#subset_df['distance_clicks'].hist(figsize=(10,10),bins=1000,log=True)

# %%
subset_df['sum_distance_clicks'].plot(figsize=(100,10))
# Out:
# <AxesSubplot:>

# %%
sum_distance_clicks_max = dps.adding_euclid_distance_sum_variable(subset_df)
sum_distance_clicks_max.hist(bins=272)
# Out:
# <AxesSubplot:>

# %%
subset_df.hist(figsize=(15,15),bins=20,log=True)
# Out:
# array([[<AxesSubplot:title={'center':'level_0'}>,
#         <AxesSubplot:title={'center':'session_id'}>,
#         <AxesSubplot:title={'center':'index'}>,
#         <AxesSubplot:title={'center':'elapsed_time'}>],
#        [<AxesSubplot:title={'center':'level'}>,
#         <AxesSubplot:title={'center':'page'}>,
#         <AxesSubplot:title={'center':'room_coor_x'}>,
#         <AxesSubplot:title={'center':'room_coor_y'}>],
#        [<AxesSubplot:title={'center':'screen_coor_x'}>,
#         <AxesSubplot:title={'center':'screen_coor_y'}>,
#         <AxesSubplot:title={'center':'hover_duration'}>,
#         <AxesSubplot:title={'center':'difference_clicks'}>],
#        [<AxesSubplot:title={'center':'distance_clicks'}>,
#         <AxesSubplot:title={'center':'screen_distance_clicks'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
# looking at only one session
session_df = subset_df[subset_df['session_id'] == 20090312431273200]
# session_df.to_csv('data/session_20090312431273200.csv', index=False)
print(session_df.shape)
# Out:
# (881, 23)

# %%
session_df['distance_clicks'].hist(figsize=(10,10),bins=20,log=True)
# Out:
# <AxesSubplot:>

# %%
session_df.hist()

# %%
labels = pd.read_csv('data/raw/train_labels.csv')
labels.head(5)
# Out:
#              session_id  correct
# 0  20090312431273200_q1        1
# 1  20090312433251036_q1        0
# 2  20090312455206810_q1        1
# 3  20090313091715820_q1        0
# 4  20090313571836404_q1        1

# %%
labels['session'] = labels.session_id.apply(lambda x: int(x.split('_')[0]) )
labels['q'] = labels.session_id.apply(lambda x: int(x.split('_')[-1][1:]) )
labels.head(5)
# Out:
#              session_id  correct            session  q
# 0  20090312431273200_q1        1  20090312431273200  1
# 1  20090312433251036_q1        0  20090312433251036  1
# 2  20090312455206810_q1        1  20090312455206810  1
# 3  20090313091715820_q1        0  20090313091715820  1
# 4  20090313571836404_q1        1  20090313571836404  1

# %%
session_labels = labels[labels['session'] == 20090312431273200]
print(f"Shape of session_labels: {session_labels.shape}")
session_labels.head(5)
# Out:
# Shape of session_labels: (18, 4)
#                  session_id  correct            session  q
# 0      20090312431273200_q1        1  20090312431273200  1
# 23562  20090312431273200_q2        1  20090312431273200  2
# 47124  20090312431273200_q3        1  20090312431273200  3
# 70686  20090312431273200_q4        1  20090312431273200  4
# 94248  20090312431273200_q5        1  20090312431273200  5

# %%
plt.figure(figsize=(3, 3))
plot_df = labels.correct.value_counts()
plot_df.plot(kind="bar", color=['b', 'c'])
# Out:
# <Axes: xlabel='correct'>

# %%
plt.figure(figsize=(10, 20))
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.suptitle("\"Correct\" column values for each question", fontsize=14, y=0.94)
for n in range(1,19):
    #print(n, str(n))
    ax = plt.subplot(6, 3, n)

    # filter df and plot ticker on the new subplot axis
    plot_df = labels.loc[labels.q == n]
    plot_df = plot_df.correct.value_counts()
    plot_df.plot(ax=ax, kind="bar", color=['b', 'c'])
    
    # chart formatting
    ax.set_title("Question " + str(n))
    ax.set_xlabel("")
