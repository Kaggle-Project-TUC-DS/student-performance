# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# get working directory and remove last folder
wd = os.path.dirname(os.getcwd())
os.chdir(wd)
print("Working Directory: ", os.getcwd())
# Out:
# Working Directory:  d:\Repos\student-performance

# %%
dtypes={
    'elapsed_time':np.int32,
    'event_name':'category',
    'name':'category',
    'level':np.uint8,
    'room_coor_x':np.float32,
    'room_coor_y':np.float32,
    'screen_coor_x':np.float32,
    'screen_coor_y':np.float32,
    'hover_duration':np.float32,
    'text':'category',
    'fqid':'category',
    'room_fqid':'category',
    'text_fqid':'category',
    'fullscreen':'category',
    'hq':'category',
    'music':'category',
    'level_group':'category'}

dataset_df = pd.read_csv('data/raw/train.csv', dtype=dtypes)

# %%
dataset_df.head(5)
# Out:
#           session_id  index  elapsed_time      event_name   name  level  page
# 0  20090312431273200      0             0  cutscene_click  basic      0   NaN  \
# 1  20090312431273200      1          1323    person_click  basic      0   NaN
# 2  20090312431273200      2           831    person_click  basic      0   NaN
# 3  20090312431273200      3          1147    person_click  basic      0   NaN
# 4  20090312431273200      4          1863    person_click  basic      0   NaN
#
#    room_coor_x  room_coor_y  screen_coor_x  screen_coor_y  hover_duration
# 0  -413.991394  -159.314682          380.0          494.0             NaN  \
# 1  -413.991394  -159.314682          380.0          494.0             NaN
# 2  -413.991394  -159.314682          380.0          494.0             NaN
# 3  -413.991394  -159.314682          380.0          494.0             NaN
# 4  -412.991394  -159.314682          381.0          494.0             NaN
#
#                             text    fqid                       room_fqid
# 0                      undefined   intro  tunic.historicalsociety.closet  \
# 1  Whatcha doing over there, Jo?  gramps  tunic.historicalsociety.closet
# 2         Just talking to Teddy.  gramps  tunic.historicalsociety.closet
# 3     I gotta run to my meeting!  gramps  tunic.historicalsociety.closet
# 4            Can I come, Gramps?  gramps  tunic.historicalsociety.closet
#
#                                            text_fqid fullscreen hq music
# 0               tunic.historicalsociety.closet.intro          0  0     1  \
# 1  tunic.historicalsociety.closet.gramps.intro_0_...          0  0     1
# 2  tunic.historicalsociety.closet.gramps.intro_0_...          0  0     1
# 3  tunic.historicalsociety.closet.gramps.intro_0_...          0  0     1
# 4  tunic.historicalsociety.closet.gramps.intro_0_...          0  0     1
#
#   level_group
# 0         0-4
# 1         0-4
# 2         0-4
# 3         0-4
# 4         0-4

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26296946 entries, 0 to 26296945
# Data columns (total 20 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   session_id      int64
#  1   index           int64
#  2   elapsed_time    int32
#  3   event_name      category
#  4   name            category
#  5   level           uint8
#  6   page            float64
#  7   room_coor_x     float32
#  8   room_coor_y     float32
#  9   screen_coor_x   float32
#  10  screen_coor_y   float32
#  11  hover_duration  float32
#  12  text            category
#  13  fqid            category
#  14  room_fqid       category
#  15  text_fqid       category
#  16  fullscreen      category
#  17  hq              category
#  18  music           category
#  19  level_group     category
# dtypes: category(10), float32(5), float64(1), int32(1), int64(2), uint8(1)
# memory usage: 1.5 GB

# %%
dataset_df.describe()
# Out:
#          session_id         index  elapsed_time         level           page
# count  2.629695e+07  2.629695e+07  2.629695e+07  2.629695e+07  564544.000000  \
# mean   2.113249e+16  6.445102e+02  4.016694e+06  1.219169e+01       3.166559
# std    5.712953e+14  5.457880e+02  3.127032e+07  6.497789e+00       2.063291
# min    2.009031e+16  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    2.101022e+16  2.880000e+02  4.397000e+05  6.000000e+00       1.000000
# 50%    2.104021e+16  5.950000e+02  1.014801e+06  1.300000e+01       3.000000
# 75%    2.110052e+16  8.960000e+02  1.747040e+06  1.800000e+01       5.000000
# max    2.210022e+16  2.047300e+04  1.988607e+09  2.200000e+01       6.000000
#
#         room_coor_x   room_coor_y  screen_coor_x  screen_coor_y
# count  2.422367e+07  2.422367e+07   2.422367e+07   2.422367e+07  \
# mean  -5.490582e+01 -1.162119e+02   4.584099e+02   3.855858e+02
# std    5.202926e+02  2.184710e+02   2.479389e+02   1.298166e+02
# min   -1.992355e+03 -9.181624e+02   0.000000e+00   0.000000e+00
# 25%   -3.528395e+02 -2.127183e+02   2.690000e+02   3.040000e+02
# 50%   -1.116280e+01 -9.760534e+01   4.470000e+02   3.970000e+02
# 75%    2.966515e+02  2.268786e+01   6.630000e+02   4.710000e+02
# max    1.261774e+03  5.436164e+02   1.919000e+03   1.440000e+03
#
#        hover_duration
# count    2.002244e+06
# mean     3.471006e+03
# std      4.602024e+05
# min      0.000000e+00
# 25%      9.900000e+01
# 50%      4.190000e+02
# 75%      1.266000e+03
# max      2.451637e+08

# %%
dataset_df.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'session_id'}>,
#         <AxesSubplot:title={'center':'index'}>,
#         <AxesSubplot:title={'center':'elapsed_time'}>],
#        [<AxesSubplot:title={'center':'level'}>,
#         <AxesSubplot:title={'center':'page'}>,
#         <AxesSubplot:title={'center':'room_coor_x'}>],
#        [<AxesSubplot:title={'center':'room_coor_y'}>,
#         <AxesSubplot:title={'center':'screen_coor_x'}>,
#         <AxesSubplot:title={'center':'screen_coor_y'}>],
#        [<AxesSubplot:title={'center':'hover_duration'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
import data_preprocessing_martin as dps

df_dps = dps.adding_new_variables(dataset_df)

df_dps = dps.feature_engineer_steve(df_dps)

# %%
import data_preprocessing_martin as dps
df_dps = dps.adding_distance_variable(df_dps)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Repos\student-performance\notebooks\playing_with_the_data.ipynb Cell 10 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Repos/student-performance/notebooks/playing_with_the_data.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> import data_preprocessing_martin as dps
# ----> <a href='vscode-notebook-cell:/d%3A/Repos/student-performance/notebooks/playing_with_the_data.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> df_dps = dps.adding_distance_variable(df_dps)
#
# File d:\Repos\student-performance\notebooks\data_preprocessing_martin.py:41, in adding_distance_variable(dataset_df)
#      40 def adding_distance_variable(dataset_df):
# ---> 41     dataset_df = dataset_df.sort_values(['session_id', 'index'])
#      42     group = dataset_df.groupby(['session_id', 'level'])
#      44     # Berechnung der Differenz zwischen den Koordinaten und Quadratur
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:6750, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6745     raise ValueError(
#    6746         f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    6747         f" != length of by ({len(by)})"
#    6748     )
#    6749 if len(by) > 1:
# -> 6750     keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6752     # need to rewrap columns in Series to apply key function
#    6753     if key is not None:
#    6754         # error: List comprehension has incompatible type List[Series];
#    6755         # expected List[ndarray]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:6750, in <listcomp>(.0)
#    6745     raise ValueError(
#    6746         f"Length of ascending ({len(ascending)})"  # type: ignore[arg-type]
#    6747         f" != length of by ({len(by)})"
#    6748     )
#    6749 if len(by) > 1:
# -> 6750     keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    6752     # need to rewrap columns in Series to apply key function
#    6753     if key is not None:
#    6754         # error: List comprehension has incompatible type List[Series];
#    6755         # expected List[ndarray]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:1778, in NDFrame._get_label_or_level_values(self, key, axis)
#    1776     values = self.axes[axis].get_level_values(key)._values
#    1777 else:
# -> 1778     raise KeyError(key)
#    1780 # Check for duplicates
#    1781 if values.ndim > 1:
#
# KeyError: 'index'

# %%
# looking at only one session
session_df = dataset_df[dataset_df['session_id'] == 20090312431273200]
# session_df.to_csv('data/session_20090312431273200.csv', index=False)
print(session_df.shape)
# Out:
# (881, 20)

# %%
session_df
# Out:
#             session_id  index  elapsed_time      event_name       name  level
# 0    20090312431273200      0             0  cutscene_click      basic      0  \
# 1    20090312431273200      1          1323    person_click      basic      0
# 2    20090312431273200      2           831    person_click      basic      0
# 3    20090312431273200      3          1147    person_click      basic      0
# 4    20090312431273200      4          1863    person_click      basic      0
# ..                 ...    ...           ...             ...        ...    ...
# 876  20090312431273200    927       1267357  navigate_click  undefined     22
# 877  20090312431273200    928       1268292       map_hover      basic     22
# 878  20090312431273200    929       1269474       map_click  undefined     22
# 879  20090312431273200    930       1270708  navigate_click  undefined     22
# 880  20090312431273200    931       1272679      checkpoint      basic     22
#
#      page  room_coor_x  room_coor_y  screen_coor_x  screen_coor_y
# 0     NaN  -413.991394  -159.314682          380.0          494.0  \
# 1     NaN  -413.991394  -159.314682          380.0          494.0
# 2     NaN  -413.991394  -159.314682          380.0          494.0
# 3     NaN  -413.991394  -159.314682          380.0          494.0
# 4     NaN  -412.991394  -159.314682          381.0          494.0
# ..    ...          ...          ...            ...            ...
# 876   NaN   927.307251   -10.355928          838.0          335.0
# 877   NaN          NaN          NaN            NaN            NaN
# 878   NaN   457.523010    22.141338          443.0          316.0
# 879   NaN   224.190323   -60.268669          404.0          337.0
# 880   NaN          NaN          NaN            NaN            NaN
#
#      hover_duration                           text             fqid
# 0               NaN                      undefined            intro  \
# 1               NaN  Whatcha doing over there, Jo?           gramps
# 2               NaN         Just talking to Teddy.           gramps
# 3               NaN     I gotta run to my meeting!           gramps
# 4               NaN            Can I come, Gramps?           gramps
# ..              ...                            ...              ...
# 876             NaN                            NaN            tomap
# 877           366.0                            NaN            tomap
# 878             NaN                            NaN  tunic.capitol_2
# 879             NaN                            NaN   chap4_finale_c
# 880             NaN                            NaN   chap4_finale_c
#
#                           room_fqid
# 0    tunic.historicalsociety.closet  \
# 1    tunic.historicalsociety.closet
# 2    tunic.historicalsociety.closet
# 3    tunic.historicalsociety.closet
# 4    tunic.historicalsociety.closet
# ..                              ...
# 876   tunic.historicalsociety.entry
# 877   tunic.historicalsociety.entry
# 878   tunic.historicalsociety.entry
# 879            tunic.capitol_2.hall
# 880            tunic.capitol_2.hall
#
#                                              text_fqid fullscreen hq music
# 0                 tunic.historicalsociety.closet.intro          0  0     1  \
# 1    tunic.historicalsociety.closet.gramps.intro_0_...          0  0     1
# 2    tunic.historicalsociety.closet.gramps.intro_0_...          0  0     1
# 3    tunic.historicalsociety.closet.gramps.intro_0_...          0  0     1
# 4    tunic.historicalsociety.closet.gramps.intro_0_...          0  0     1
# ..                                                 ...        ... ..   ...
# 876                                                NaN          0  0     1
# 877                                                NaN          0  0     1
# 878                                                NaN          0  0     1
# 879                                                NaN          0  0     1
# 880                                                NaN          0  0     1
#
#     level_group
# 0           0-4
# 1           0-4
# 2           0-4
# 3           0-4
# 4           0-4
# ..          ...
# 876       13-22
# 877       13-22
# 878       13-22
# 879       13-22
# 880       13-22
#
# [881 rows x 20 columns]

# %%
labels = pd.read_csv('data/raw/train_labels.csv')
labels.head(5)
# Out:
#              session_id  correct
# 0  20090312431273200_q1        1
# 1  20090312433251036_q1        0
# 2  20090312455206810_q1        1
# 3  20090313091715820_q1        0
# 4  20090313571836404_q1        1

# %%
labels['session'] = labels.session_id.apply(lambda x: int(x.split('_')[0]) )
labels['q'] = labels.session_id.apply(lambda x: int(x.split('_')[-1][1:]) )
labels.head(5)
# Out:
#              session_id  correct            session  q
# 0  20090312431273200_q1        1  20090312431273200  1
# 1  20090312433251036_q1        0  20090312433251036  1
# 2  20090312455206810_q1        1  20090312455206810  1
# 3  20090313091715820_q1        0  20090313091715820  1
# 4  20090313571836404_q1        1  20090313571836404  1

# %%
session_labels = labels[labels['session'] == 20090312431273200]
print(f"Shape of session_labels: {session_labels.shape}")
session_labels.head(5)
# Out:
# Shape of session_labels: (18, 4)
#                  session_id  correct            session  q
# 0      20090312431273200_q1        1  20090312431273200  1
# 23562  20090312431273200_q2        1  20090312431273200  2
# 47124  20090312431273200_q3        1  20090312431273200  3
# 70686  20090312431273200_q4        1  20090312431273200  4
# 94248  20090312431273200_q5        1  20090312431273200  5

# %%
plt.figure(figsize=(3, 3))
plot_df = labels.correct.value_counts()
plot_df.plot(kind="bar", color=['b', 'c'])
# Out:
# <Axes: xlabel='correct'>

# %%
plt.figure(figsize=(10, 20))
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.suptitle("\"Correct\" column values for each question", fontsize=14, y=0.94)
for n in range(1,19):
    #print(n, str(n))
    ax = plt.subplot(6, 3, n)

    # filter df and plot ticker on the new subplot axis
    plot_df = labels.loc[labels.q == n]
    plot_df = plot_df.correct.value_counts()
    plot_df.plot(ax=ax, kind="bar", color=['b', 'c'])
    
    # chart formatting
    ax.set_title("Question " + str(n))
    ax.set_xlabel("")
